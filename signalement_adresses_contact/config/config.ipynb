# %%
# Installations
# %pip install pyodbc
# Out:
# Looking in indexes: http://10.4.3.215:8081/repository/pypi-all/simple
# Collecting pyodbc
#   Downloading http://10.4.3.215:8081/repository/pypi-all/packages/pyodbc/5.3.0/pyodbc-5.3.0-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (350 kB)
# Installing collected packages: pyodbc
# Successfully installed pyodbc-5.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import technique commun
import pyodbc
import pandas as pd

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)
pd.set_option("display.width", 120)

# %%
# Parametrage de la connexion
server = "PRD-DBDW-P01.soclebi-prod.esante.gouv.fr" 
database = "BICOEUR_DWH_SNAPSHOT"

conn = pyodbc.connect(
    "DRIVER={ODBC Driver 17 for SQL Server};"
    "SERVER=PRD-DBDW-P01.soclebi-prod.esante.gouv.fr;"
    "DATABASE=BICOEUR_DWH_SNAPSHOT;"
    "Trusted_Connection=yes;"
)

print("Connexion OK")
# Out:
# Connexion OK
